# %%
import pandas as pd
import numpy as np

# %%
from distutils import errors


dados = pd.read_csv(r"C:\Users\petri\Documents\Shark-Attack\archive\attacks.csv", 
                encoding = 'latin-1')

# %%
dados
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
dados['Area'].value_counts()
# Out:
# Florida                                 1037
# New South Wales                          486
# Queensland                               311
# Hawaii                                   298
# California                               290
#                                         ...
# Ysabel Island                              1
#  Lau Province                              1
# South Coast, East New Britain              1
# Between Southampton & Canary Islands       1
# Moala Island                               1
# Name: Area, Length: 825, dtype: int64

# %%
dados.groupby('Country')['Country' ].count().sort_values()
# Out:
# Country
#  PHILIPPINES                1
# NORTH ATLANTIC OCEAN        1
# NICARAGUA                   1
# NEVIS                       1
# NETHERLANDS ANTILLES        1
#                          ...
# NEW ZEALAND               128
# PAPUA NEW GUINEA          134
# SOUTH AFRICA              579
# AUSTRALIA                1338
# USA                      2229
# Name: Country, Length: 212, dtype: int64

# %%
dados['Sex '].value_counts()
# Out:
# M      5094
# F       637
# M         2
# N         2
# lli       1
# .         1
# Name: Sex , dtype: int64

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
dados['Year'].unique()
# Out:
# array([2018., 2017.,   nan, 2016., 2015., 2014., 2013., 2012., 2011.,
#        2010., 2009., 2008., 2007., 2006., 2005., 2004., 2003., 2002.,
#        2001., 2000., 1999., 1998., 1997., 1996., 1995., 1984., 1994.,
#        1993., 1992., 1991., 1990., 1989., 1969., 1988., 1987., 1986.,
#        1985., 1983., 1982., 1981., 1980., 1979., 1978., 1977., 1976.,
#        1975., 1974., 1973., 1972., 1971., 1970., 1968., 1967., 1966.,
#        1965., 1964., 1963., 1962., 1961., 1960., 1959., 1958., 1957.,
#        1956., 1955., 1954., 1953., 1952., 1951., 1950., 1949., 1948.,
#        1848., 1947., 1946., 1945., 1944., 1943., 1942., 1941., 1940.,
#        1939., 1938., 1937., 1936., 1935., 1934., 1933., 1932., 1931.,
#        1930., 1929., 1928., 1927., 1926., 1925., 1924., 1923., 1922.,
#        1921., 1920., 1919., 1918., 1917., 1916., 1915., 1914., 1913.,
#        1912., 1911., 1910., 1909., 1908., 1907., 1906., 1905., 1904.,
# ...

# %% [markdown]
# Removendo dados nulos

# %%
#Removendo coluna com muitos valores nulos

dados.drop(columns = ['Unnamed: 22', 'Unnamed: 23'], inplace = True)
dados
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
#Procurando valores nulos  na coluna 'Year' 
dados[dados['Year'].isnull()]
# Out:
#         Case Number                  Date  Year        Type    Country  \
# 187    2017.01.08.R  Reported 08-Jan-2017   NaN     Invalid  AUSTRALIA
# 6079   1836.08.19.R  Reported 19-Aug-1836   NaN  Unprovoked    ENGLAND
# 6302              0                   NaN   NaN         NaN        NaN
# 6303              0                   NaN   NaN         NaN        NaN
# 6304              0                   NaN   NaN         NaN        NaN
# ...             ...                   ...   ...         ...        ...
# 25718           NaN                   NaN   NaN         NaN        NaN
# 25719           NaN                   NaN   NaN         NaN        NaN
# 25720           NaN                   NaN   NaN         NaN        NaN
# 25721           NaN                   NaN   NaN         NaN        NaN
# 25722            xx                   NaN   NaN         NaN        NaN
#
#              Area    Location      Activity          Name Sex   ...  \
# ...

# %%
dados.iloc[[187, 6079],[1,2]]
# Out:
#                       Date  Year
# 187   Reported 08-Jan-2017   NaN
# 6079  Reported 19-Aug-1836   NaN

# %%
#Alterando o valor nulo por uma data correta

dados.loc[187, 'Year'] = 2017
dados.loc[6079, 'Year']= 1836

# %%
dados.iloc[[187, 6079],[1,2]]
# Out:
#                       Date    Year
# 187   Reported 08-Jan-2017  2017.0
# 6079  Reported 19-Aug-1836  1836.0

# %%
#Alterando os valores nulos por 0 para mudar pro tipo "int"

dados['Year'].fillna(0, inplace=True)

# %%
dados['Year'] = dados['Year'].astype("int")

# %%
dados['Year']
# Out:
# 0        2018
# 1        2018
# 2        2018
# 3        2018
# 4        2018
#          ...
# 25718       0
# 25719       0
# 25720       0
# 25721       0
# 25722       0
# Name: Year, Length: 25723, dtype: int32

# %%
dados.head()
# Out:
#   Case Number         Date  Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
#   Fatal (Y/N)           Time         Species           Investigator or Source  \
# ...

# %%
#visualizando o 'Year' por odem decrescente

dados.groupby('Year', as_index=False).count().sort_values(by='Year', ascending= False)
# Out:
#      Year  Case Number  Date  Type  Country  Area  Location  Activity  Name  \
# 248  2018           53    53    53       53    50        53        52    52
# 247  2017          137   137   136      136   130       127       131   133
# 246  2016          130   130   130      130   124       124       124   129
# 245  2015          143   143   142      143   135       138       137   143
# 244  2014          127   127   127      126   117       114       122   126
# ..    ...          ...   ...   ...      ...   ...       ...       ...   ...
# 4    1543            1     1     1        1     1         0         1     1
# 3     500            1     1     1        1     0         0         0     1
# 2      77            1     1     1        0     1         0         1     1
# 1       5            1     1     1        1     1         1         0     1
# 0       0         2526   125   125      121    99        91       107   120
#
# ...

# %%
dados['Year'].describe()
# Out:
# count    25723.000000
# mean       472.171559
# std        840.498090
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       2018.000000
# Name: Year, dtype: float64

# %% [markdown]
# Criando mascara com os dados depois de 2010

# %%
#Mascara para utilizar os dados de 2010 em diante
mascara = dados['Year'] >= 2010

# %%
dados_mascara = dados[mascara]
dados_mascara.head()
# Out:
#   Case Number         Date  Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
#   Fatal (Y/N)           Time         Species           Investigator or Source  \
# ...

# %%
dados_mascara[['Year']].value_counts().sort_values(ascending=False)
# Out:
# Year
# 2015    143
# 2017    137
# 2016    130
# 2011    128
# 2014    127
# 2013    122
# 2012    117
# 2010    101
# 2018     53
# dtype: int64

# %%
dados_mascara['Area'].value_counts()
# Out:
# Florida              230
# New South Wales       84
# Hawaii                73
# Western Australia     66
# California            62
#                     ...
# Granada                1
# Majorca                1
# Central Tuamotu        1
# Washington             1
# Eastern Province       1
# Name: Area, Length: 171, dtype: int64

# %%
dados_mascara.head()
# Out:
#   Case Number         Date  Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
#   Fatal (Y/N)           Time         Species           Investigator or Source  \
# ...

# %% [markdown]
# Alterando dados NaN de Area

# %%
dados_mascara[dados_mascara['Area'].isnull()]
# Out:
#        Case Number                   Date  Year          Type  \
# 32      2018.04.09            09-Apr-2018  2018    Unprovoked
# 33      2018.04.05            05-Apr-2018  2018    Unprovoked
# 48      2018.01.21            21-Jan-2018  2018    Unprovoked
# 56      2017.12.09            09-Dec-2017  2017    Unprovoked
# 59    2017.11.25.R   Reported 25-Nov-2017  2017  Sea Disaster
# 62    2017.11.13.R   Reported 13-Nov-2017  2017    Unprovoked
# 90    2017.09.06.R   Reported 06-Sep-2017  2017    Unprovoked
# 101     2017.08.18            18-Aug-2017  2017    Unprovoked
# 129   2017.06.18.a            18-Jun-2017  2017    Unprovoked
# 132   2017.06.14.R   Reported 14-Jun-2017  2017    Unprovoked
# 206   2016.10.13.R            13-Oct-2016  2016       Invalid
# 226     2016.09.00               Sep-2016  2016       Invalid
# 229     2016.08.27            27-Aug-2016  2016    Unprovoked
# 248   2016.07.14.R  Reported  14-Jul-2016  2016    Unprovoked
# ...

# %%
dados_mascara.iloc[[32,33], [4,5,6]]
# Out:
#           Country Area               Location
# 32  NEW CALEDONIA  NaN  Magenta Beach, Noumea
# 33        BAHAMAS  NaN                 Bimini

# %%
#Alterando os dados nulos de 'Area'

dados_mascara.loc[32, 'Area']= 'Noumea'
dados_mascara.loc[33, 'Area']= 'Bimini'

# %%
dados_mascara.iloc[[48,56,59,90,101,129,132,206,226], [4,5,6]]
# Out:
#              Country Area          Location
# 48     NEW CALEDONIA  NaN          Nouville
# 56           BAHAMAS  NaN               NaN
# 59             LIBYA  NaN    Gars Garabulli
# 90   SOLOMON ISLANDS  NaN    Owarigi Island
# 101          BAHAMAS  NaN               NaN
# 129          REUNION  NaN      Roches Noire
# 132          BAHAMAS  NaN               NaN
# 206           MEXICO  NaN  Guadalupe Island
# 226           MEXICO  NaN  Guadalupe Island

# %%
dados_mascara.loc[48, 'Area']= 'Nouville'
dados_mascara.loc[[56,101,132], ['Area', 'Location']]= 'Bahamas'
dados_mascara.loc[59, 'Area'] = 'Gars Garabulli'
dados_mascara.loc[90, 'Area'] = 'Owarigi Island'
dados_mascara.loc[129, 'Area'] = 'Roches Noire'
dados_mascara.loc[[206,226], 'Area'] = 'Guadalupe Island'

# %%
dados_mascara.iloc[[229,248,270,296,325,327,370,388], [4,5,6]]
# Out:
#            Country Area                Location
# 229        REUNION  NaN            Boucan Canot
# 248        BAHAMAS  NaN             Tiger Beach
# 270  NEW CALEDONIA  NaN   Côte-Blanche, Nouméa
# 296        BAHAMAS  NaN                     NaN
# 325          ARUBA  NaN           Boat capsized
# 327        BAHAMAS  NaN       Off Andros Island
# 370           FIJI  NaN                     NaN
# 388        REUNION  NaN                 St. Leu

# %%
dados_mascara.iloc[[229,248,270,296,325,327,370,388], [4,5,6]]
# Out:
#            Country Area                Location
# 229        REUNION  NaN            Boucan Canot
# 248        BAHAMAS  NaN             Tiger Beach
# 270  NEW CALEDONIA  NaN   Côte-Blanche, Nouméa
# 296        BAHAMAS  NaN                     NaN
# 325          ARUBA  NaN           Boat capsized
# 327        BAHAMAS  NaN       Off Andros Island
# 370           FIJI  NaN                     NaN
# 388        REUNION  NaN                 St. Leu

# %%
#Substituindo os nulos de 'Area' por dados da 'Location'.

dados_mascara.loc[dados_mascara['Area'].isnull(), 'Area']= dados_mascara.loc[dados_mascara['Area'].isnull(),'Location']

# %%
##Substituindo os nulos de 'Area' por dados da 'Country'.

dados_mascara.loc[dados_mascara['Area'].isnull(), 'Area']= dados_mascara.loc[dados_mascara['Area'].isnull(),'Country']

# %%
##Substituindo os nulos de 'Location' por dados da 'Area'.

dados_mascara.loc[dados_mascara['Location'].isnull(), 'Location']= dados_mascara.loc[dados_mascara['Location'].isnull(),'Area']

# %%
dados_mascara[['Country','Area', 'Location']]
# Out:
#            Country                Area                        Location
# 0              USA          California     Oceanside, San Diego County
# 1              USA             Georgia  St. Simon Island, Glynn County
# 2              USA              Hawaii                    Habush, Oahu
# 3        AUSTRALIA     New South Wales              Arrawarra Headland
# 4           MEXICO              Colima                        La Ticla
# ...            ...                 ...                             ...
# 1053       VIETNAM  Binh Dinh Province                       Quy Nhon
# 1054       VIETNAM  Binh Dinh Province                       Quy Nhon
# 1055       VIETNAM  Binh Dinh Province                       Quy Nhon
# 1056           USA             Florida                      Elliot Key
# 1057  SOUTH AFRICA    Eastern Province             Nahoon, East London
#
# [1058 rows x 3 columns]

# %%
dados_mascara[dados_mascara['Area'].isnull()]
# Out:
#       Case Number                  Date  Year        Type Country Area  \
# 62   2017.11.13.R  Reported 13-Nov-2017  2017  Unprovoked     NaN  NaN
# 525    2014.08.00              Aug-2014  2014     Invalid     NaN  NaN
#
#     Location      Activity            Name Sex   ... Fatal (Y/N) Time  \
# 62       NaN       Surfing   Timur Yunusov    M  ...           N  NaN
# 525      NaN  Sea disaster  Cuban refugees    M  ...         NaN  NaN
#
#                             Species         Investigator or Source  \
# 62                               NaN                     Instagram
# 525  Shark involvement not confirmed  Associated Press, 11/27/2014
#
#                                pdf  \
# 62          2017.11.13.R-Timur.pdf
# 525  2014.08.00-Cuban-refugees.pdf
#
#                                           href formula  \
# 62   http://sharkattackfile.net/spreadsheets/pdf_di...
# 525  http://sharkattackfile.net/spreadsheets/pdf_di...
#
# ...

# %%
dados_mascara.iloc[[543], [4,5,6]]
# Out:
#     Country                                Area  \
# 543  BRAZIL  500 km off the coast of Pernambuco
#
#                                Location
# 543  500 km off the coast of Pernambuco

# %%
dados_mascara.loc[543, 'Area']= 'Coast of Pernambuco'

# %%
#Removendo linha com nulo em 'Country', 'Area' e 'Location'

dados_mascara.drop(index=62, inplace=True)
# Out:
# C:\Users\petri\AppData\Local\Temp\ipykernel_14892\1434763476.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_mascara.drop(index=62, inplace=True)

# %%
dados_mascara.drop(index=525, inplace=True)
# Out:
# C:\Users\petri\AppData\Local\Temp\ipykernel_14892\1443425636.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_mascara.drop(index=525, inplace=True)

# %%
dados_mascara[dados_mascara['Area'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Case Number, Date, Year, Type, Country, Area, Location, Activity, Name, Sex , Age, Injury, Fatal (Y/N), Time, Species , Investigator or Source, pdf, href formula, href, Case Number.1, Case Number.2, original order]
# Index: []
#
# [0 rows x 22 columns]

# %%
dados_mascara['Area'].value_counts()
# Out:
# Florida                                  230
# New South Wales                           84
# Hawaii                                    73
# Western Australia                         66
# California                                62
#                                         ...
# Cargados Carajos Shoals (St. Brandon)      1
# Moorea                                     1
# Castellón                                  1
# Maryland                                   1
# Eastern Province                           1
# Name: Area, Length: 215, dtype: int64

# %%
#Visualizaçaõ dos 5 paises com mais ataques
dados_mascara['Country'].value_counts().head(5).plot.bar()
# Out:
# <AxesSubplot:>

# %%
#Criando grafico

import matplotlib.pyplot as plt
import seaborn as sns


plt.style.use('seaborn-white')
sns.set(style="white")
sns.color_palette("deep")
sns.set_color_codes('deep')


fig = plt.figure(figsize=(18, 18))
ax1 = plt.subplot2grid((3,3), (0,0), colspan=2)
plt.title('Áreas com maior número de ataques de tubarão entre 2010 e 2018')


g1 = sns.countplot(x="Area", data=dados_mascara, palette='afmhot', order=dados_mascara.Area.value_counts().iloc[:5].index, ax=ax1)

# %%
dados_mascara['Fatal (Y/N)'].value_counts()
# Out:
# N          903
# Y           74
# UNKNOWN      2
# Name: Fatal (Y/N), dtype: int64

# %%
dados_mascara['Fatal (Y/N)']= dados_mascara['Fatal (Y/N)'].str.replace('M', 'N')
dados_mascara['Fatal (Y/N)']= dados_mascara['Fatal (Y/N)'].str.replace('2017', 'UNKNOWN')
# Out:
# C:\Users\petri\AppData\Local\Temp\ipykernel_14892\590554791.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_mascara['Fatal (Y/N)']= dados_mascara['Fatal (Y/N)'].str.replace('M', 'N')
# C:\Users\petri\AppData\Local\Temp\ipykernel_14892\590554791.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_mascara['Fatal (Y/N)']= dados_mascara['Fatal (Y/N)'].str.replace('2017', 'UNKNOWN')

# %%
dados_mascara[dados_mascara['Fatal (Y/N)'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Case Number, Date, Year, Type, Country, Area, Location, Activity, Name, Sex , Age, Injury, Fatal (Y/N), Time, Species , Investigator or Source, pdf, href formula, href, Case Number.1, Case Number.2, original order]
# Index: []
#
# [0 rows x 22 columns]

# %%
#Transformando nulos em 'UNKNOWN'

dados_mascara.loc[dados_mascara['Fatal (Y/N)'].isnull(), 'Fatal (Y/N)'] ='UNKNOWN'

# %%
dados_mascara[dados_mascara['Fatal (Y/N)'] == 'UNKNOWN']
# Out:
#        Case Number         Date  Year        Type       Country  \
# 27    2018.04.15.c  15-Apr-2018  2018  Unprovoked        BRAZIL
# 76      2017.10.01  01-Oct-2017  2017     Invalid  SOUTH AFRICA
# 79    2017.09.24.b  24-Sep-2017  2017     Invalid           USA
# 84    2017.09.15.b  15-Sep-2017  2017     Invalid  SOUTH AFRICA
# 98    2017.08.26.b  26-Aug-2017  2017     Invalid         SPAIN
# ...            ...          ...   ...         ...           ...
# 953     2011.01.20  20-Jan-2011  2011     Invalid     AUSTRALIA
# 967     2010.11.27  27-Nov-2010  2010     Invalid     AUSTRALIA
# 994     2010.08.29  29-Aug-2010  2010     Invalid       BAHAMAS
# 1003    2010.08.05  05-Aug-2010  2010     Invalid           USA
# 1044    2010.02.04  04-Feb-2010  2010     Invalid          GUAM
#
#                        Area                               Location  \
# 27               Pernambuco                                Piedade
# ...

# %%
dados_mascara['Fatal (Y/N)'].value_counts()

#No total de 1056 casos, 74 foram fatais.
# Out:
# N          903
# UNKNOWN     79
# Y           74
# Name: Fatal (Y/N), dtype: int64

# %%
valor_total = 1056
mortes = 74

print((mortes/valor_total) *100)
# Out:
# 7.007575757575757

# %%
dados_mascara['Year'].value_counts()

#O ano de 2015 foi o que teve mais ataques
# Out:
# 2015    143
# 2017    136
# 2016    130
# 2011    128
# 2014    126
# 2013    122
# 2012    117
# 2010    101
# 2018     53
# Name: Year, dtype: int64

# %%
fatais = dados_mascara['Fatal (Y/N)'] == 'Y'

# %%
casos_fatais = dados_mascara[fatais]
casos_fatais['Year'].value_counts()

#O ano de 2011 foi que mais teve casos fatais
# Out:
# 2011    14
# 2013    13
# 2015     9
# 2012     9
# 2017     8
# 2010     8
# 2014     7
# 2016     5
# 2018     1
# Name: Year, dtype: int64
