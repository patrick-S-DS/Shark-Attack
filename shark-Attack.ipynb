# %%
import pandas as pd
import numpy as np

# %%
from distutils import errors


dados = pd.read_csv(r"C:\Users\petri\Documents\Shark-Attack\archive\attacks.csv", 
                encoding = 'latin-1')

# %%
dados
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
dados.groupby('Country')['Country' ].count().sort_values()
# Out:
# Country
#  PHILIPPINES                1
# NORTH ATLANTIC OCEAN        1
# NICARAGUA                   1
# NEVIS                       1
# NETHERLANDS ANTILLES        1
#                          ...
# NEW ZEALAND               128
# PAPUA NEW GUINEA          134
# SOUTH AFRICA              579
# AUSTRALIA                1338
# USA                      2229
# Name: Country, Length: 212, dtype: int64

# %%
dados['Sex '].value_counts()
# Out:
# M      5094
# F       637
# M         2
# N         2
# lli       1
# .         1
# Name: Sex , dtype: int64

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %% [markdown]
# Date, age, time,  esta como obj
#
# Qual a prevalencia de ataque de tubarao no Brasil entre 2010 e 2018
# qual especie que mais atacou no brasil

# %%
dados_brazil = dados[dados['Country'] == 'BRAZIL']

# %%
dados_brazil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112 entries, 6 to 6101
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             112 non-null    object
#  1   Date                    112 non-null    object
#  2   Year                    112 non-null    float64
#  3   Type                    112 non-null    object
#  4   Country                 112 non-null    object
#  5   Area                    104 non-null    object
#  6   Location                107 non-null    object
#  7   Activity                103 non-null    object
#  8   Name                    107 non-null    object
#  9   Sex                     98 non-null     object
#  10  Age                     64 non-null     object
#  11  Injury                  110 non-null    object
#  12  Fatal (Y/N)             104 non-null    object
#  13  Time                    43 non-null     object
# ...

# %%
dados_brazil[['Sex ']].reset_index().describe
# Out:
# <bound method NDFrame.describe of      index Sex
# 0        6    M
# 1       27    M
# 2       31    M
# 3       44    F
# 4       51    M
# ..     ...  ...
# 107   5122  NaN
# 108   5746    M
# 109   5777    M
# 110   5848    M
# 111   6101    M
#
# [112 rows x 2 columns]>

# %%
dados_brazil['Species '].value_counts()
# Out:
# Bull shark                                            3
# Shark involvement not confirmed                       3
# Bull or tiger shark                                   3
# Tiger shark                                           2
# 2 m shark                                             2
# Sandtiger shark                                       2
# Tiger shark, 1.5 m                                    2
# Shark involvement prior to death was not confirmed    2
# Thought to involve a white, bull or tiger shark       1
# White shark                                           1
# 170-kg, 2.8 m shark                                   1
#                                                       1
# 3.7m  to 4.2 m white shark                            1
# Though to involve a white shark                       1
# Tiger shark, 2.5 m [8.25']                            1
# 1.3 to 1.6 m shark                                    1
# 2.27 m shark                                          1
# ...

# %% [markdown]
# Verificando dados nulos em 'Year'.

# %%
dados['Year'].dtype
# Out:
# dtype('float64')

# %%
dados_brazil[dados_brazil['Year'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Case Number, Date, Year, Type, Country, Area, Location, Activity, Name, Sex , Age, Injury, Fatal (Y/N), Time, Species , Investigator or Source, pdf, href formula, href, Case Number.1, Case Number.2, original order, Unnamed: 22, Unnamed: 23]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# Verificando dados dos USA

# %%
dados_usa = dados[dados['Country'] == 'USA']
dados_usa.reset_index()
# Out:
#       index   Case Number                Date    Year        Type Country  \
# 0         0    2018.06.25         25-Jun-2018  2018.0     Boating     USA
# 1         1    2018.06.18         18-Jun-2018  2018.0  Unprovoked     USA
# 2         2    2018.06.09         09-Jun-2018  2018.0     Invalid     USA
# 3         7    2018.05.27         27-May-2018  2018.0  Unprovoked     USA
# 4         8  2018.05.26.b         26-May-2018  2018.0  Unprovoked     USA
# ...     ...           ...                 ...     ...         ...     ...
# 2224   6249       ND.0056         Before 1958     0.0  Unprovoked     USA
# 2225   6283       ND.0019         Before 1921     0.0  Unprovoked     USA
# 2226   6288       ND.0014  Before 17-Jul-1916     0.0  Unprovoked     USA
# 2227   6292       ND.0010          Circa 1862     0.0  Unprovoked     USA
# 2228   6299       ND.0003           1900-1905     0.0  Unprovoked     USA
#
#                  Area                                           Location  \
# ...

# %%
dados_usa['Area'].value_counts()
# Out:
# Florida                   1037
# Hawaii                     298
# California                 290
# South Carolina             159
# North Carolina             101
# Texas                       73
# New Jersey                  52
# New York                    30
# Oregon                      29
# Virginia                    19
# Massachusetts               16
# Puerto Rico                 16
# Alabama                     15
# Georgia                     14
# Louisiana                   11
# Maryland                     7
# Delaware                     7
# Rhode Island                 7
# Connecticut                  6
# Mississippi                  5
# US Virgin Islands            5
# New York                     3
# North Carolina               2
# Palmyra Atoll                2
# East coast                   2
# Washington                   2
# Midway Atoll                 1
#  North Carolina              1
# Wake Island                  1
# Illinois                     1
# ...

# %%
dados_usa['Species '].value_counts()
# Out:
# Shark involvement not confirmed                       53
# White shark                                           43
# 4' shark                                              38
# Invalid                                               32
# Shark involvement prior to death was not confirmed    30
#                                                       ..
# 1.2 m [4'] "grey-colored shark"                        1
# Questionable Incident                                  1
# Mako shark, 1.8 m [6']                                 1
# 2.4 m to 3.7 m [8' to 12'] shark                       1
# White shark, 1,900-lb                                  1
# Name: Species , Length: 640, dtype: int64

# %% [markdown]
# Limpeza de dados 'Area' e 'Year'

# %%
dados[dados['Year'].isnull()]
# Out:
#         Case Number                  Date  Year        Type    Country  \
# 187    2017.01.08.R  Reported 08-Jan-2017   NaN     Invalid  AUSTRALIA
# 6079   1836.08.19.R  Reported 19-Aug-1836   NaN  Unprovoked    ENGLAND
# 6302              0                   NaN   NaN         NaN        NaN
# 6303              0                   NaN   NaN         NaN        NaN
# 6304              0                   NaN   NaN         NaN        NaN
# ...             ...                   ...   ...         ...        ...
# 25718           NaN                   NaN   NaN         NaN        NaN
# 25719           NaN                   NaN   NaN         NaN        NaN
# 25720           NaN                   NaN   NaN         NaN        NaN
# 25721           NaN                   NaN   NaN         NaN        NaN
# 25722            xx                   NaN   NaN         NaN        NaN
#
#              Area    Location      Activity          Name Sex   ...  \
# ...

# %%
dados.iloc[[187, 6079],[1,2]]
# Out:
#                       Date  Year
# 187   Reported 08-Jan-2017   NaN
# 6079  Reported 19-Aug-1836   NaN

# %%
dados.loc[187, 'Year'] = 2017
dados.loc[6079, 'Year']= 1836

# %%
dados.iloc[[187, 6079],[1,2]]
# Out:
#                       Date    Year
# 187   Reported 08-Jan-2017  2017.0
# 6079  Reported 19-Aug-1836  1836.0

# %%
dados['Yaer'] = dados['Year'].astype("int")
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# c:\Users\petri\Documents\Shark-Attack\shark-Attack.ipynb Célula: 24 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/petri/Documents/Shark-Attack/shark-Attack.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> dados['Yaer'] = dados['Year'].astype("int")
#
# File c:\Users\petri\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# ...

# %%
dados[['Year']].value_counts()
# Out:
# Year
# 2015.0    143
# 2017.0    137
# 2016.0    130
# 2011.0    128
# 2014.0    127
#          ...
# 1807.0      1
# 1805.0      1
# 1804.0      1
# 1802.0      1
# 1791.0      1
# Length: 249, dtype: int64

# %%
dados['Year'].describe()
# Out:
# count    6302.000000
# mean     1927.272136
# std       281.076315
# min         0.000000
# 25%      1942.000000
# 50%      1977.000000
# 75%      2005.000000
# max      2018.000000
# Name: Year, dtype: float64

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6302 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
dados['Case Number']
# Out:
# 0        2018.06.25
# 1        2018.06.18
# 2        2018.06.09
# 3        2018.06.08
# 4        2018.06.04
#             ...
# 25718           NaN
# 25719           NaN
# 25720           NaN
# 25721           NaN
# 25722            xx
# Name: Case Number, Length: 25723, dtype: object

# %%
dados['Year'].unique()
# Out:
# array([2018., 2017., 2016., 2015., 2014., 2013., 2012., 2011., 2010.,
#        2009., 2008., 2007., 2006., 2005., 2004., 2003., 2002., 2001.,
#        2000., 1999., 1998., 1997., 1996., 1995., 1984., 1994., 1993.,
#        1992., 1991., 1990., 1989., 1969., 1988., 1987., 1986., 1985.,
#        1983., 1982., 1981., 1980., 1979., 1978., 1977., 1976., 1975.,
#        1974., 1973., 1972., 1971., 1970., 1968., 1967., 1966., 1965.,
#        1964., 1963., 1962., 1961., 1960., 1959., 1958., 1957., 1956.,
#        1955., 1954., 1953., 1952., 1951., 1950., 1949., 1948., 1848.,
#        1947., 1946., 1945., 1944., 1943., 1942., 1941., 1940., 1939.,
#        1938., 1937., 1936., 1935., 1934., 1933., 1932., 1931., 1930.,
#        1929., 1928., 1927., 1926., 1925., 1924., 1923., 1922., 1921.,
#        1920., 1919., 1918., 1917., 1916., 1915., 1914., 1913., 1912.,
#        1911., 1910., 1909., 1908., 1907., 1906., 1905., 1904., 1903.,
# ...
